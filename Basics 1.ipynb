# %% [markdown]
# # print function

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Literal Constants

# %% [markdown]
# ### integer

# %%
a=5
print(a)
type(a)
# Out:
# 5
# int

# %% [markdown]
# ### float

# %%
b=10.99999

# %%
print(b)
# Out:
# 10.99999

# %%
type(b)
# Out:
# float

# %% [markdown]
# ### complex

# %%
c=10+5j

# %%
print(c)
# Out:
# (10+5j)

# %%
type(c)
# Out:
# complex

# %% [markdown]
# # String

# %%
a='samar loves python'
type(a)
# Out:
# str

# %%
a="rahul loves python"
type(a)
# Out:
# str

# %%
a='''
this is
triple single
quotes
'''
type(a)
# Out:
# str

# %%
a="""
this is
triple double
quotes
"""
type(a)
# Out:
# str

# %% [markdown]
# # Multiple Variable assignment

# %%
a,b,c = 10,20,30.39

# %%
print(a,b,c)
# Out:
# 10 20 30.39
